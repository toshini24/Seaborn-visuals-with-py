# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
flight = sns.load_dataset('flights')

# %%
sns.boxplot(x='year', y='passengers', data=flight)

# %%
sns.boxplot(x='passengers', y='month', data=flight)

# %%
sns.barplot(x='passengers', y='month', data=flight)

# %%
sns.barplot(x='year', y='passengers', data=flight)

# %%
sns.violinplot(x='passengers', y='month', data=flight)

# %%
sns.violinplot(x='year', y='passengers', data=flight)

# %%
sns.stripplot(x='passengers', y='month', data=flight)

# %%
sns.stripplot(x='year', y='passengers', data=flight)

# %%
sns.pointplot(x='passengers', y='month', data=flight)

# %%
sns.pointplot(x='year', y='passengers', data=flight)

# %%
sns.residplot(x='year', y='passengers', data=flight)

# %%
sns.swarmplot(x='passengers', y='month', data=flight)

# %%
sns.swarmplot(x='year', y='passengers', data=flight)

# %%
print(dir(sns))
# Out:
# ['FacetGrid', 'JointGrid', 'PairGrid', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__path__', '__spec__', '__version__', '_orig_rc_params', 'algorithms', 'axes_style', 'axisgrid', 'barplot', 'blend_palette', 'boxplot', 'categorical', 'choose_colorbrewer_palette', 'choose_cubehelix_palette', 'choose_dark_palette', 'choose_diverging_palette', 'choose_light_palette', 'clustermap', 'cm', 'color_palette', 'countplot', 'crayon_palette', 'crayons', 'cubehelix_palette', 'dark_palette', 'desaturate', 'despine', 'distplot', 'distributions', 'diverging_palette', 'external', 'factorplot', 'get_dataset_names', 'heatmap', 'hls_palette', 'husl_palette', 'jointplot', 'kdeplot', 'light_palette', 'lmplot', 'load_dataset', 'lvplot', 'matrix', 'miscplot', 'mpl', 'mpl_palette', 'pairplot', 'palettes', 'palplot', 'plotting_context', 'pointplot', 'rcmod', 'regplot', 'regression', 'reset_defaults', 'reset_orig', 'residplot', 'rugplot', 'saturate', 'set', 's
# ...

# %%
sns.distplot(flight['year'],bins=10)
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.set(); np.random.seed(0)
x = np.random.randn(100)
ax = sns.distplot(x)
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
tips=sns.load_dataset('tips')
sns.distplot(tips['tip'], hist=None)

# %%
#sns.set(style='ticks')
cols = ['total_bill','tip']
sns.pairplot(tips[cols], palette='Blues', size=3, markers=True )

# %%
sns.pairplot(tips, hue='sex', x_vars=['total_bill','tip'], y_vars=['size','day'])

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
